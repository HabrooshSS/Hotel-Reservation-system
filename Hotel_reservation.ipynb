# %%
class Guest:
    def __init__(self, guest_id, name, email, phone_number, credit_card_details):
        self.__guest_id = guest_id
        self.__name = name
        self.__email = email
        self.__phone_number = phone_number
        self.__credit_card_details = credit_card_details

    # Getters
    def get_guest_id(self):
        return self.__guest_id

    def get_name(self):
        return self.__name

    def get_email(self):
        return self.__email

    def get_phone_number(self):
        return self.__phone_number

    def get_credit_card_details(self):
        return self.__credit_card_details

    # Setters
    def set_name(self, name):
        self.__name = name

    def set_email(self, email):
        self.__email = email

    def set_phone_number(self, phone_number):
        self.__phone_number = phone_number

    # Methods for Reservation
    def make_reservation(self, reservation_details):
        """
        This method should make a reservation using the details provided.
        """
        pass

    def cancel_reservation(self, reservation_id):
        """
        This method should cancel a reservation based on the reservation ID.
        """
        pass

    def view_reservation(self, reservation_id):
        """
        This method should allow a guest to view their reservation details.
        """
        pass

# %%
class Reservation:
    def __init__(self, reservation_id, check_in_date, check_out_date, room_type, total_cost, status):
        self.__reservation_id = reservation_id
        self.__check_in_date = check_in_date
        self.__check_out_date = check_out_date
        self.__room_type = room_type
        self.__total_cost = total_cost
        self.__status = status

    # Getters
    def get_reservation_id(self):
        return self.__reservation_id

    def get_check_in_date(self):
        return self.__check_in_date

    def get_check_out_date(self):
        return self.__check_out_date

    def get_room_type(self):
        return self.__room_type

    def get_total_cost(self):
        return self.__total_cost

    def get_status(self):
        return self.__status

    # Setters
    def set_check_in_date(self, check_in_date):
        self.__check_in_date = check_in_date

    def set_check_out_date(self, check_out_date):
        self.__check_out_date = check_out_date

    def set_room_type(self, room_type):
        self.__room_type = room_type

    def set_total_cost(self, total_cost):
        self.__total_cost = total_cost

    def set_status(self, status):
        self.__status = status

    # Methods
    def modify_reservation(self, new_details):
        """
        This method should modify the reservation with new details.
        """
        pass

    def get_reservation_details(self):
        """
        This method should return a string with the reservation details.
        """
        pass

# %%
class Payment:
    def __init__(self, payment_id, payment_amount, payment_date, payment_method, is_refunded=False):
        self.__payment_id = payment_id
        self.__payment_amount = payment_amount
        self.__payment_date = payment_date
        self.__payment_method = payment_method
        self.__is_refunded = is_refunded

    # Getters
    def get_payment_id(self):
        return self.__payment_id

    def get_payment_amount(self):
        return self.__payment_amount

    def get_payment_date(self):
        return self.__payment_date

    def get_payment_method(self):
        return self.__payment_method

    def is_payment_refunded(self):
        return self.__is_refunded

    # Setters
    def set_payment_amount(self, payment_amount):
        self.__payment_amount = payment_amount

    def set_payment_date(self, payment_date):
        self.__payment_date = payment_date

    def set_payment_method(self, payment_method):
        self.__payment_method = payment_method

    def refund_payment(self):
        self.__is_refunded = True

    # Methods
    def process_payment(self, payment_details):
        """
        This method should process the payment and return True if successful.
        """
        pass

    def refund_payment(self, payment_id):
        """
        This method should handle the refund process.
        """
        pass

# %%
class Room:
    def __init__(self, room_id, room_type, room_price, is_available=True):
        self.__room_id = room_id
        self.__room_type = room_type
        self.__room_price = room_price
        self.__is_available = is_available

    # Getters
    def get_room_id(self):
        return self.__room_id

    def get_room_type(self):
        return self.__room_type

    def get_room_price(self):
        return self.__room_price

    def is_room_available(self):
        return self.__is_available

    # Setters
    def set_room_type(self, room_type):
        self.__room_type = room_type

    def set_room_price(self, room_price):
        self.__room_price = room_price

    def set_availability(self, is_available):
        self.__is_available = is_available

    # Methods
    def check_availability(self, check_in_date, check_out_date):
        """
        This method should check if the room is available between the check-in and check-out dates.
        """
        pass

    def assign_room(self):
        """
        This method should assign a room to a reservation.
        """
        pass

# %%
class Receipt:
    def __init__(self, receipt_id, guest_id, reservation_id, amount_paid, payment_date):
        self.__receipt_id = receipt_id
        self.__guest_id = guest_id
        self.__reservation_id = reservation_id
        self.__amount_paid = amount_paid
        self.__payment_date = payment_date

    # Getters
    def get_receipt_id(self):
        return self.__receipt_id

    def get_guest_id(self):
        return self.__guest_id

    def get_reservation_id(self):
        return self.__reservation_id

    def get_amount_paid(self):
        return self.__amount_paid

    def get_payment_date(self):
        return self.__payment_date

    # Methods
    def generate_receipt(self, reservation_id, payment_id):
        """
        This method should generate a receipt based on the reservation and payment details.
        """
        pass

# %%
class HotelStaff:
    def __init__(self, staff_id, name, role):
        self.__staff_id = staff_id
        self.__name = name
        self.__role = role

    # Getters
    def get_staff_id(self):
        return self.__staff_id

    def get_name(self):
        return self.__name

    def get_role(self):
        return self.__role

    # Methods
    def check_in_guest(self, reservation_id):
        """
        This method should handle checking in a guest based on their reservation ID.
        """
        pass

    def modify_reservation(self, reservation_id, new_details):
        """
        This method should allow the hotel staff to modify a reservation on behalf of the guest.
        """
        pass

    def cancel_reservation(self, reservation_id):
        """
        This method should allow hotel staff to cancel a guest's reservation.
        """
        pass

# %%
# Create Guest object
guest = Guest(guest_id=1, name="Ted Vera", email="tedvera@mac.com", phone_number="555-1234", credit_card_details="Mastercard (ending in 9904)")

# Create Room object
room = Room(room_id=101, room_type="2 Queen Beds /No Smoking/Desk/Safe /Coffee Maker In Room/Hair Dryer", room_price=89.95)

# Create Reservation object
reservation = Reservation(
    reservation_id=15549850358,
    check_in_date="Sun, Aug 22, 2010 - 03:00 PM",
    check_out_date="Tue, Aug 24, 2010 - 12:00 PM",
    room_type=room.get_room_type(),
    total_cost=201.48,
    status="Confirmed"
)

# Create Payment object
payment = Payment(payment_id=123456, payment_amount=201.48, payment_date="Aug 22, 2010", payment_method="Mastercard (ending in 9904)")

# Create Receipt object
receipt = Receipt(receipt_id=1, guest_id=guest.get_guest_id(), reservation_id=reservation.get_reservation_id(), amount_paid=payment.get_payment_amount(), payment_date=payment.get_payment_date())

# Display the information as shown in the figure
print("Your Reservation Is Confirmed")
print("Thank you for your reservation. Please print your hotel receipt and show it at check in.")
print(f"Your Name: {guest.get_name()}")
print(f"Your Email: {guest.get_email()}")
print(f"Priceline Trip Number: {reservation.get_reservation_id()}")
print("Hotel Confirmation Number: 52253687\n")

print("Comfort Inn & Suites Los Alamos")
print("2455 Trinity Drive")
print("Los Alamos, NM 87544")
print(f"Check-In: {reservation.get_check_in_date()}")
print(f"Check-Out: {reservation.get_check_out_date()}")
print(f"Number of Nights: 2")
print(f"Number of Rooms: 1\n")
print(f"Room 1: {guest.get_name()}")
print(f"Room Type: {room.get_room_type()}\n")

print("Summary of Charges")
print(f"Billing Name: {guest.get_name()}")
print(f"Credit Card: {guest.get_credit_card_details()}")
print(f"Room Cost: {room.get_room_price()} avg. per room, per night")
print("Rooms: 1")
print("Nights: 2")
print(f"Room Subtotal: ${room.get_room_price() * 2:.2f}")
print("Taxes and Fees: $21.58")
print(f"Total Charges: ${payment.get_payment_amount()}")
# Out:
# Your Reservation Is Confirmed
# Thank you for your reservation. Please print your hotel receipt and show it at check in.
# Your Name: Ted Vera
# Your Email: tedvera@mac.com
# Priceline Trip Number: 15549850358
# Hotel Confirmation Number: 52253687
#
# Comfort Inn & Suites Los Alamos
# 2455 Trinity Drive
# Los Alamos, NM 87544
# Check-In: Sun, Aug 22, 2010 - 03:00 PM
# Check-Out: Tue, Aug 24, 2010 - 12:00 PM
# Number of Nights: 2
# Number of Rooms: 1
#
# Room 1: Ted Vera
# Room Type: 2 Queen Beds /No Smoking/Desk/Safe /Coffee Maker In Room/Hair Dryer
#
# Summary of Charges
# Billing Name: Ted Vera
# Credit Card: Mastercard (ending in 9904)
# Room Cost: 89.95 avg. per room, per night
# Rooms: 1
# Nights: 2
# Room Subtotal: $179.90
# Taxes and Fees: $21.58
# Total Charges: $201.48
